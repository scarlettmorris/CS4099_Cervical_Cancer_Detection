# %%
from load_data import inspect_arrays, get_arrays

# %% [markdown]
# ## Code below to be run once the new_processed_data.npz arrays have been split into train_data.npz, validate_data.npz and test_data.npz

# %%
train_filenames, train_features, train_labels, train_labels_numeric = get_arrays("new_train_data.npz")
inspect_arrays(train_filenames, train_features, train_labels, train_labels_numeric)
# Out:
# ['filenames', 'features', 'labels', 'labels_numeric']
# Filenames shape: (1745963,)
# Features shape: (1745963, 1024)
# Labels shape: (1745963,)
# Labels numeric shape: (1745963,)

# %%
validate_filenames, validate_features, validate_labels, validate_labels_numeric = get_arrays("new_validate_data.npz")
inspect_arrays(validate_filenames, validate_features, validate_labels, validate_labels_numeric)
# Out:
# ['filenames', 'features', 'labels', 'labels_numeric']
# Filenames shape: (832582,)
# Features shape: (832582, 1024)
# Labels shape: (832582,)
# Labels numeric shape: (832582,)

# %%
test_filenames, test_features, test_labels, test_labels_numeric = get_arrays("new_test_data.npz")
inspect_arrays(test_filenames, test_features, test_labels, test_labels_numeric)
# Out:
# ['filenames', 'features', 'labels', 'labels_numeric']
# Filenames shape: (987600,)
# Features shape: (987600, 1024)
# Labels shape: (987600,)
# Labels numeric shape: (987600,)
